# %% [markdown]
# # Lesson 3 Class Exercises: Pandas Part 1
#
# With these class exercises we learn a few new things.  When new knowledge is introduced you'll see the icon shown on the right:
# <span style="float:right; margin-left:10px; clear:both;">![Task](../media/new_knowledge.png)</span>

# %% [markdown]
# ## Reminder
# The first checkin-in of the project is due next Tueday.  After today, you should have everything you need to know to accomplish that first part.

# %% [markdown]
# ## Get Started
# Import the Numpy and Pandas packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1: Import Iris Data
# Import the Iris dataset made available to you in the last class period for the Numpy part2 exercises. Save it to a variable naemd `iris`. Print the first 5 rows and the dimensions to ensure it was read in properly.

# %%
iris = pd.read_csv('data/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Notice how much easier this was to import compared to the Numpy `genfromtxt`. We did not have to skip the headers, we did not have to specify the data type and we can have mixed data types in the same matrix.

# %% [markdown]
# ## Exercise 2: Import Legislators Data
# For portions of this notebook we will use a public dataset that contains all of the current legistators of the United States Congress. This dataset can be found [here](https://github.com/unitedstates/congress-legislators).
#
# Import the data directly from this URL:  https://theunitedstates.io/congress-legislators/legislators-current.csv
#
# Save the data in a variable named `legistators`. Print the first 5 lines, and the dimensions. You can get the dimensions of the dataframe using the `.shape` member variable.

# %%
legislators = pd.read_csv('https://theunitedstates.io/congress-legislators/legislators-current.csv')
legislators.head(5)
# Out:
#   last_name first_name middle_name suffix nickname             full_name  \
# 0     Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1  Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2    Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3    Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4     Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
#
#      birthday gender type state  ...  opensecrets_id  lis_id  \
# 0  1952-11-09      M  sen    OH  ...       N00003535    S307
# 1  1958-10-13      F  sen    WA  ...       N00007836    S275
# 2  1943-10-05      M  sen    MD  ...       N00001955    S308
# 3  1947-01-23      M  sen    DE  ...       N00012508    S277
# 4  1960-04-13      M  sen    PA  ...       N00027503    S309
#
#                fec_ids cspan_id govtrack_id votesmart_id  ballotpedia_id  \
# 0  H2OH13033,S6OH00163   5051.0      400050      27018.0   Sherrod Brown
# 1  S8WA00194,H2WA01054  26137.0      300018      27122.0  Maria Cantwell
# 2  H6MD03177,S6MD03177   4004.0      400064      26888.0      Ben Cardin
# 3            S8DE00079    663.0      300019      22421.0      Tom Carper
# 4            S6PA00217  47036.0      412246       2541.0  Bob Casey, Jr.
#
#   washington_post_id icpsr_id    wikipedia_id
# 0                NaN  29389.0   Sherrod Brown
# 1                NaN  39310.0  Maria Cantwell
# 2                NaN  15408.0      Ben Cardin
# 3                NaN  15015.0      Tom Carper
# 4                NaN  40703.0   Bob Casey Jr.
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Exercise 3: Explore the Data
# ### Task 1
# Print the column names of the legistators dataframe and explore the type of data in the data frame.

# %%
legislators.columns
# Out:
# Index(['last_name', 'first_name', 'middle_name', 'suffix', 'nickname',
#        'full_name', 'birthday', 'gender', 'type', 'state', 'district',
#        'senate_class', 'party', 'url', 'address', 'phone', 'contact_form',
#        'rss_url', 'twitter', 'twitter_id', 'facebook', 'youtube', 'youtube_id',
#        'mastodon', 'bioguide_id', 'thomas_id', 'opensecrets_id', 'lis_id',
#        'fec_ids', 'cspan_id', 'govtrack_id', 'votesmart_id', 'ballotpedia_id',
#        'washington_post_id', 'icpsr_id', 'wikipedia_id'],
#       dtype='object')

# %% [markdown]
# ### Task 2
# Show the data types of all of the columns in the legislator data. To do this, use the `.dtype` member variable. Do all of the data types seem appropriate for the data?

# %%
# legislators.dtypes
legislators['district']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 535    0.0
# 536    3.0
# 537    3.0
# 538    0.0
# 539    NaN
# Name: district, Length: 540, dtype: float64

# %% [markdown]
# Show all of the data types in the iris dataframe. To do this, use the `.dtype` member variable.

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ### Task 3
# It's always important to know where the missing values are in your data. Are there any missing values in the legislators dataframe? How many per column?
#
# Hint: we didn't learn how to find missing values in the lesson, but we can use the `isna()` function.

# %%
legislators.isna().sum()
# Out:
# last_name               0
# first_name              0
# middle_name           266
# suffix                520
# nickname              506
# full_name               0
# birthday                0
# gender                  0
# type                    0
# state                   0
# district              100
# senate_class          440
# party                   0
# url                     4
# address                 0
# phone                   0
# contact_form          441
# rss_url               337
# twitter                44
# twitter_id             44
# facebook              235
# youtube               325
# youtube_id            259
# mastodon              525
# bioguide_id             0
# thomas_id             267
# opensecrets_id         80
# lis_id                440
# fec_ids                 0
# cspan_id              224
# govtrack_id             0
# votesmart_id          124
# ballotpedia_id        101
# washington_post_id    540
# icpsr_id              156
# wikipedia_id            3
# dtype: int64

# %% [markdown]
# How about in the iris dataframe?

# %%
iris.sepal_width.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal_width, Length: 150, dtype: bool

# %% [markdown]
# ### Task 4
# It is also important to know if you have any duplicatd rows. If you are performing statistcal analyses and you have duplicated entries they can affect the results.  So, let's find out.  Are there any duplicated rows in the legislators dataframe?  Print then number of duplicates. If there are duplicates print the rows. What function could we used to find out if we have duplicated rows?

# %%
legislators[legislators.duplicated(subset=['full_name'],keep=False)]
# Out:
#     last_name first_name middle_name suffix nickname        full_name  \
# 7    Menendez     Robert         NaN    NaN      Bob  Robert Menendez
# 505  Menendez     Robert    Jacobsen    Jr.      NaN  Robert Menendez
#
#        birthday gender type state  ...  opensecrets_id  lis_id  \
# 7    1954-01-01      M  sen    NJ  ...       N00000699    S306
# 505  1985-07-12      M  rep    NJ  ...             NaN     NaN
#
#                  fec_ids cspan_id govtrack_id votesmart_id ballotpedia_id  \
# 7    H2NJ13075,S6NJ00289  29608.0      400272      26961.0   Bob Menendez
# 505            H2NJ08232      NaN      456918          NaN            NaN
#
#     washington_post_id icpsr_id  wikipedia_id
# 7                  NaN  29373.0  Bob Menendez
# 505                NaN      NaN  Rob Menendez
#
# [2 rows x 36 columns]

# %% [markdown]
# Do we have duplicated rows in the iris dataset? Print the number of duplicates? If there are duplicates print the rows.

# %%
iris.duplicated().sum()
# Out:
# 3

# %%
iris[iris.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 34            4.9          3.1           1.5          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 142           5.8          2.7           5.1          1.9  virginica

# %% [markdown]
# If there are duplicated rows should we remove them or keep them?

# %% [markdown]
# ### Task 5
# It is important to also check that the range of values in our data matches expectations.  For example, if we expect to have four species in our iris data, we should check that we see four species. How many political parties should we expect in the legislators data?  If all we saw were a single part perhaps the data is incomplete.... Let's check.   You can find out how many unique values there are per column using the `nunique` function.  Try it for both the legislators and the iris data set.

# %%
iris.species.nunique()
# Out:
# 3

# %%
legislators.party.nunique()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# What do you think?  Do we see what we might expect?  Are there fields where this type of check doesn't matter? In what fields might this type of exploration matter?

# %% [markdown]
# Check to see if you have all of the values expected for a given field. Pick a column you know should have a set number of values and print all of the unique values in that column. Do so for both the legislator and iris datasets.

# %% [markdown]
# ## Exercise 5: Describe the data
# For both the legislators and the iris data, get descriptive statistics for each numeric field.

# %%
legislators.describe()

# %%
iris.describe()

# %% [markdown]
# ## Exercise 6: Row Index Labels
# For the legislator dataframe, let's change the row labels from numerical indexes to something more recognizable.  Take a look at the columns of data, is there anything you might want to substitue as a row label?  Pick one and set the index lables. Then print the top 5 rows to see if the index labels are present.

# %%
'''
you can index by state, name, etc.
'''

legislators.index = legislators['state']
legislators.head(10)
# Out:
#        last_name first_name middle_name suffix nickname             full_name  \
# state
# OH         Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# WA      Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# MD        Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# DE        Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# PA         Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
# CA     Feinstein     Dianne         NaN    NaN      NaN      Dianne Feinstein
# MN     Klobuchar        Amy        Jean    NaN      NaN         Amy Klobuchar
# NJ      Menendez     Robert         NaN    NaN      Bob       Robert Menendez
# VT       Sanders    Bernard         NaN    NaN   Bernie       Bernard Sanders
# MI      Stabenow     Debbie         Ann    NaN      NaN       Debbie Stabenow
#
#          birthday gender type state  ...  opensecrets_id  lis_id  \
# state                                ...
# OH     1952-11-09      M  sen    OH  ...       N00003535    S307
# WA     1958-10-13      F  sen    WA  ...       N00007836    S275
# MD     1943-10-05      M  sen    MD  ...       N00001955    S308
# DE     1947-01-23      M  sen    DE  ...       N00012508    S277
# PA     1960-04-13      M  sen    PA  ...       N00027503    S309
# CA     1933-06-22      F  sen    CA  ...       N00007364    S221
# MN     1960-05-25      F  sen    MN  ...       N00027500    S311
# NJ     1954-01-01      M  sen    NJ  ...       N00000699    S306
# VT     1941-09-08      M  sen    VT  ...       N00000528    S313
# MI     1950-04-29      F  sen    MI  ...       N00004118    S284
#
#                    fec_ids cspan_id govtrack_id votesmart_id  \
# state
# OH     H2OH13033,S6OH00163   5051.0      400050      27018.0
# WA     S8WA00194,H2WA01054  26137.0      300018      27122.0
# MD     H6MD03177,S6MD03177   4004.0      400064      26888.0
# DE               S8DE00079    663.0      300019      22421.0
# PA               S6PA00217  47036.0      412246       2541.0
# CA               S0CA00199  13061.0      300043      53273.0
# MN               S6MN00267  83701.0      412242      65092.0
# NJ     H2NJ13075,S6NJ00289  29608.0      400272      26961.0
# VT     H8VT01016,S4VT00033    994.0      400357      27110.0
# MI     S8MI00281,H6MI08163  45451.0      300093        515.0
#
#          ballotpedia_id washington_post_id icpsr_id      wikipedia_id
# state
# OH        Sherrod Brown                NaN  29389.0     Sherrod Brown
# WA       Maria Cantwell                NaN  39310.0    Maria Cantwell
# MD           Ben Cardin                NaN  15408.0        Ben Cardin
# DE           Tom Carper                NaN  15015.0        Tom Carper
# PA       Bob Casey, Jr.                NaN  40703.0     Bob Casey Jr.
# CA     Dianne Feinstein                NaN  49300.0  Dianne Feinstein
# MN        Amy Klobuchar                NaN  40700.0     Amy Klobuchar
# NJ         Bob Menendez                NaN  29373.0      Bob Menendez
# VT       Bernie Sanders                NaN  29147.0    Bernie Sanders
# MI      Debbie Stabenow                NaN  29732.0   Debbie Stabenow
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Exercise 7: Indexing & Sampling
# Randomly select 15 Republicans or Democrats (your choice) from the senate.

# %%
# legislators.index = legislators['type']
# dems = legislators.loc['sen']
# dems.index = dems['party']
# dems.loc['Democrat'].sample(15)

'''
ko:
legislators[(legislators["party"]== "Democrat") & (legislators["type"]== "sen")].sample(15)
'''
legislators[(legislators["party"]== "Democrat") & (legislators["type"]== "sen")].sample(15)
# Out:
#        last_name   first_name middle_name suffix nickname  \
# type
# sen   Blumenthal      Richard         NaN    NaN      NaN
# sen       Cardin     Benjamin          L.    NaN      NaN
# sen       Ossoff          Jon         NaN    NaN      NaN
# sen        Kaine      Timothy         NaN    NaN      Tim
# sen        Coons  Christopher      Andrew    NaN      NaN
# sen      Manchin          Joe         NaN    III      NaN
# sen       Hirono        Mazie          K.    NaN      NaN
# sen       Tester          Jon         NaN    NaN      NaN
# sen       Warner         Mark          R.    NaN      NaN
# sen    Klobuchar          Amy        Jean    NaN      NaN
# sen    Duckworth        Tammy         NaN    NaN      NaN
# sen       Markey       Edward          J.    NaN       Ed
# sen    Fetterman         John        Karl    NaN      NaN
# sen        Brown      Sherrod         NaN    NaN      NaN
# sen        Luján          Ben         Ray    NaN      NaN
#
#                  full_name    birthday gender type state  ...  opensecrets_id  \
# type                                                      ...
# sen     Richard Blumenthal  1946-02-13      M  sen    CT  ...       N00031685
# sen     Benjamin L. Cardin  1943-10-05      M  sen    MD  ...       N00001955
# sen             Jon Ossoff  1987-02-16      M  sen    GA  ...       N00040675
# sen              Tim Kaine  1958-02-26      M  sen    VA  ...       N00033177
# sen   Christopher A. Coons  1963-09-09      M  sen    DE  ...       N00031820
# sen       Joe Manchin, III  1947-08-24      M  sen    WV  ...       N00032838
# sen        Mazie K. Hirono  1947-11-03      F  sen    HI  ...       N00028139
# sen             Jon Tester  1956-08-21      M  sen    MT  ...       N00027605
# sen         Mark R. Warner  1954-12-15      M  sen    VA  ...       N00002097
# sen          Amy Klobuchar  1960-05-25      F  sen    MN  ...       N00027500
# sen        Tammy Duckworth  1968-03-12      F  sen    IL  ...       N00027860
# sen       Edward J. Markey  1946-07-11      M  sen    MA  ...       N00000270
# sen         John Fetterman  1969-08-15      M  sen    PA  ...             NaN
# sen          Sherrod Brown  1952-11-09      M  sen    OH  ...       N00003535
# sen          Ben Ray Luján  1972-06-07      M  sen    NM  ...       N00029562
#
#       lis_id              fec_ids   cspan_id govtrack_id votesmart_id  \
# type
# sen     S341            S0CT00177    21799.0      412490       1568.0
# sen     S308  H6MD03177,S6MD03177     4004.0      400064      26888.0
# sen     S414  H8GA06195,S8GA00180        NaN      456857     176134.0
# sen     S362            S2VA00142    49219.0      412582      50772.0
# sen     S337            S0DE00092  9269028.0      412390     122834.0
# sen     S338            S0WV00090    62864.0      412391       7547.0
# sen     S361  H6HI02251,S2HI00106    91216.0      412200       1677.0
# sen     S314            S6MT00162  1020176.0      412244      20928.0
# sen     S327  S6VA00093,P80003023     7630.0      412321        535.0
# sen     S311            S6MN00267    83701.0      412242      65092.0
# sen     S386  H6IL06141,S6IL00292    94484.0      412533      57442.0
# sen     S369  H6MA07101,S4MA00028      260.0      400253      26900.0
# sen     S418            S6PA00274        NaN      456877     166286.0
# sen     S307  H2OH13033,S6OH00163     5051.0      400050      27018.0
# sen     S409  H8NM03196,S0NM00058  1031351.0      412293     102842.0
#
#           ballotpedia_id washington_post_id icpsr_id        wikipedia_id
# type
# sen   Richard Blumenthal                NaN  41101.0  Richard Blumenthal
# sen           Ben Cardin                NaN  15408.0          Ben Cardin
# sen           Jon Ossoff                NaN      NaN          Jon Ossoff
# sen            Tim Kaine                NaN  41305.0           Tim Kaine
# sen          Chris Coons                NaN  40916.0         Chris Coons
# sen      Joe Manchin III                NaN  40915.0         Joe Manchin
# sen      Mazie K. Hirono                NaN  20713.0        Mazie Hirono
# sen           Jon Tester                NaN  40702.0          Jon Tester
# sen          Mark Warner                NaN  40909.0         Mark Warner
# sen        Amy Klobuchar                NaN  40700.0       Amy Klobuchar
# sen      Tammy Duckworth                NaN  21325.0     Tammy Duckworth
# sen            Ed Markey                NaN  14435.0           Ed Markey
# sen       John Fetterman                NaN      NaN      John Fetterman
# sen        Sherrod Brown                NaN  29389.0       Sherrod Brown
# sen        Ben Ray Luján                NaN  20932.0       Ben Ray Luján
#
# [15 rows x 36 columns]

# %% [markdown]
# ## Exercise 8: Dates
# <span style="float:right; margin-left:10px; clear:both;">![Task](../media/new_knowledge.png)</span>
# Let's learn something not covered in the Pandas 1 lesson regarding dates.  We have the birthdates for each legislator, but they are in a String format.  Let's convert it to a datetime object. We can do this using the `pd.to_datetime` function.  Take a look at the online documentation to see how to use this function. Convert the `legislators['birthday']` column to a `datetime` object. Confirm that the column is now a datetime object.

# %%
legislators['birthday'].head()
# Out:
# type
# sen    1952-11-09
# sen    1958-10-13
# sen    1943-10-05
# sen    1947-01-23
# sen    1960-04-13
# Name: birthday, dtype: object

# %%
# pd.to_datetime(legislators['birthday'].head())
legislators['birthday'] = pd.to_datetime(legislators['birthday'])

# %% [markdown]
# Now that we have the birthdays in a `datetime` object, how can we calculate their age?  Hint: we can use the `pd.Timestamp.now()` function to get a datetime object for this moment. Let's subtract the current time from their birthdays.  Print the top 5 results.

# %%
pd.Timestamp.now() - legislators['birthday']
timed = pd.Timestamp.now() - legislators['birthday']
print(timed)
#and we get a timedelta
# Out:
# type
# sen   25673 days 11:34:26.443004
# sen   23509 days 11:34:26.443004
# sen   28996 days 11:34:26.443004
# sen   27790 days 11:34:26.443004
# sen   22961 days 11:34:26.443004
#                  ...
# rep   20018 days 11:34:26.443004
# rep   12680 days 11:34:26.443004
# rep   19519 days 11:34:26.443004
# rep   22043 days 11:34:26.443004
# sen   21372 days 11:34:26.443004
# Name: birthday, Length: 540, dtype: timedelta64[ns]

# %% [markdown]
# Notice that the result of subtracting two `datetime` objects is a `timedelta` object. It contains the difference between two time values. The value we calculated therefore gives us the number of days old.  However, we want the number of years.
#
# To get the number of years we can divide the number of days old by the number of days in a year (i.e. 365). However, we need to extract out the days from the `datetime` object. To get this, the Pandas Series object has an accessor for extracting components of `datetime` objects and `timedelta` objects. It's named `dt` and it works for both.  You can learn more about the attributes of this accessor at the [datetime objects page](https://pandas.pydata.org/pandas-docs/stable/reference/series.html#datetime-properties) and the [timedelta objects page](https://pandas.pydata.org/pandas-docs/stable/reference/series.html#timedelta-properties) by clicking.  Take a moment to look over that documentation.
#
# How would then extract the days in order to divide by 365 to get the years?  Once you've figurd it out. Do so, convert the years to an integer and add the resulting series back into the legislator dataframe as a new column named `age`.  Hint: use the [astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.astype.html) function of Pandas to convert the type.

# %%
years = timed.dt.days/365
(timed.dt.days/365).astype('int').head(10)
legislators['years'] = years.astype('int32')
legislators['years']
# Out:
# type
# sen    70
# sen    64
# sen    79
# sen    76
# sen    62
#        ..
# rep    54
# rep    34
# rep    53
# rep    60
# sen    58
# Name: years, Length: 540, dtype: int32

# %% [markdown]
# Next, find the youngest, oldest and average age of all legislators

# %%
legislators.years.describe()
# Out:
# count    540.000000
# mean      58.361111
# std       12.340905
# min       26.000000
# 25%       49.000000
# 50%       59.000000
# 75%       68.000000
# max       89.000000
# Name: years, dtype: float64

# %% [markdown]
# Who are the oldest and youngest legislators?

# %%
# legislators.years.min()
# legislators[legislators['years'] == legislators['years'].min()] |

legislators[(legislators['years'] == legislators['years'].min()) | \
            (legislators['years'] == legislators['years'].max())]

#doesn't work :(     
# legislators[(legislators.years == legislators.years.min()) | \
#             (legislators.years == legislators.years..max())]
# Out:
#       last_name first_name middle_name suffix nickname         full_name  \
# type
# sen   Feinstein     Dianne         NaN    NaN      NaN  Dianne Feinstein
# sen    Grassley    Charles          E.    NaN    Chuck    Chuck Grassley
# rep       Frost    Maxwell   Alejandro    NaN      NaN     Maxwell Frost
#
#        birthday gender type state  ...  lis_id    fec_ids cspan_id  \
# type                               ...
# sen  1933-06-22      F  sen    CA  ...    S221  S0CA00199  13061.0
# sen  1933-09-17      M  sen    IA  ...    S153  S0IA00028   1167.0
# rep  1997-01-17      M  rep    FL  ...     NaN  H2FL10259      NaN
#
#      govtrack_id votesmart_id    ballotpedia_id washington_post_id icpsr_id  \
# type
# sen       300043      53273.0  Dianne Feinstein                NaN  49300.0
# sen       300048      53293.0    Chuck Grassley                NaN  14226.0
# rep       456890          NaN               NaN                NaN      NaN
#
#           wikipedia_id  years
# type
# sen   Dianne Feinstein     89
# sen     Chuck Grassley     89
# rep      Maxwell Frost     26
#
# [3 rows x 37 columns]

# %% [markdown]
# ## Exercise 9:  Indexing with loc and iloc
# Reindex the legislators dataframe using the state, and find all legislators from a state of your choice using the `loc` accessor.

# %%
# legislators.index = legislators['type']
# dems = legislators.loc['sen']
# dems.index = dems['party']
# dems.loc['Democrat'].sample(15)

legislators.index = legislators['state']
legislators.loc['WA']
# Out:
#                last_name first_name middle_name suffix nickname  \
# state
# WA              Cantwell      Maria         NaN    NaN      NaN
# WA                Larsen       Rick         NaN    NaN      NaN
# WA      McMorris Rodgers      Cathy        Anne    NaN      NaN
# WA                Murray      Patty         NaN    NaN      NaN
# WA                 Smith       Adam         NaN    NaN      NaN
# WA               DelBene      Suzan          K.    NaN      NaN
# WA                Kilmer      Derek         NaN    NaN      NaN
# WA              Newhouse        Dan         NaN    NaN      NaN
# WA               Jayapal    Pramila         NaN    NaN      NaN
# WA               Schrier        Kim         NaN    NaN      NaN
# WA            Strickland    Marilyn         NaN    NaN      NaN
# WA     Gluesenkamp Perez      Marie         NaN    NaN      NaN
#
#                      full_name   birthday gender type state  ...  lis_id  \
# state                                                        ...
# WA              Maria Cantwell 1958-10-13      F  sen    WA  ...    S275
# WA                 Rick Larsen 1965-06-15      M  rep    WA  ...     NaN
# WA      Cathy McMorris Rodgers 1969-05-22      F  rep    WA  ...     NaN
# WA                Patty Murray 1950-10-11      F  sen    WA  ...    S229
# WA                  Adam Smith 1965-06-15      M  rep    WA  ...     NaN
# WA            Suzan K. DelBene 1962-02-17      F  rep    WA  ...     NaN
# WA                Derek Kilmer 1974-01-01      M  rep    WA  ...     NaN
# WA                Dan Newhouse 1955-07-10      M  rep    WA  ...     NaN
# WA             Pramila Jayapal 1965-09-21      F  rep    WA  ...     NaN
# WA                 Kim Schrier 1968-08-23      F  rep    WA  ...     NaN
# WA          Marilyn Strickland 1962-09-25      F  rep    WA  ...     NaN
# WA     Marie Gluesenkamp Perez 1988-06-06      F  rep    WA  ...     NaN
#
#                    fec_ids   cspan_id govtrack_id votesmart_id  \
# state
# WA     S8WA00194,H2WA01054    26137.0      300018      27122.0
# WA               H0WA02080    86610.0      400232      56231.0
# WA               H4WA05077  1013063.0      400659       3217.0
# WA               S2WA00189    25277.0      300076      53358.0
# WA               H6WA09025    44329.0      400379        845.0
# WA               H0WA08046  1033929.0      412505     126272.0
# WA               H2WA06129    68310.0      412583      51516.0
# WA               H4WA04104    78315.0      412660      51522.0
# WA               H6WA07458  9267128.0      412730     153141.0
# WA               H8WA08189        NaN      412835     181124.0
# WA               H0WA10034        NaN      456854          NaN
# WA               H2WA03217        NaN      456949          NaN
#
#                 ballotpedia_id washington_post_id icpsr_id  \
# state
# WA              Maria Cantwell                NaN  39310.0
# WA                 Rick Larsen                NaN  20145.0
# WA      Cathy McMorris Rodgers                NaN  20535.0
# WA                Patty Murray                NaN  49308.0
# WA                  Adam Smith                NaN  29768.0
# WA               Suzan DelBene                NaN  31101.0
# WA                Derek Kilmer                NaN  21368.0
# WA                Dan Newhouse                NaN  21556.0
# WA             Pramila Jayapal                NaN  21726.0
# WA                 Kim Schrier                NaN  21962.0
# WA                         NaN                NaN      NaN
# WA     Marie Gluesenkamp Perez                NaN      NaN
#
#                              wikipedia_id  years
# state
# WA                         Maria Cantwell     64
# WA                            Rick Larsen     57
# WA                 Cathy McMorris Rodgers     53
# WA                           Patty Murray     72
# WA     Adam Smith (Washington politician)     57
# WA                          Suzan DelBene     61
# WA                           Derek Kilmer     49
# WA                           Dan Newhouse     67
# WA                        Pramila Jayapal     57
# WA                            Kim Schrier     54
# WA                     Marilyn Strickland     60
# WA                Marie Gluesenkamp Perez     34
#
# [12 rows x 37 columns]

# %% [markdown]
# Use the loc command to find all legislators from South Carolina and North Carolina

# %%
# legislators.loc[['SC', 'NC']]
legislators.loc[['SC', 'NC']]

#double brackets tell you the list of the values
# Out:
#       last_name       first_name          middle_name suffix nickname  \
# state
# SC       Graham          Lindsey                   O.    NaN      NaN
# SC      Clyburn            James                   E.    NaN      Jim
# SC       Duncan             Jeff                  NaN    NaN      NaN
# SC        Scott              Tim                  NaN    NaN      NaN
# SC       Wilson              Joe                   G.    NaN      NaN
# SC       Norman            Ralph                  NaN    NaN      NaN
# SC      Timmons          William                   R.    NaN      NaN
# SC         Mace            Nancy                 Ruth    NaN      NaN
# SC          Fry          Russell              William    NaN      NaN
# NC         Foxx         Virginia                  NaN    NaN      NaN
# NC      McHenry          Patrick                   T.    NaN      NaN
# NC       Hudson          Richard                  NaN    NaN      NaN
# NC        Adams             Alma                   S.    NaN      NaN
# NC       Rouzer            David                  NaN    NaN      NaN
# NC       Tillis             Thom                  NaN    NaN      NaN
# NC         Budd              Ted                  NaN    NaN      NaN
# NC       Bishop              Dan                  NaN    NaN      NaN
# NC       Murphy          Gregory              Francis    NaN      NaN
# NC         Ross          Deborah                 Koff    NaN      NaN
# NC      Manning            Kathy                Ellen    NaN      NaN
# NC        Davis           Donald                 Gene    NaN      NaN
# NC      Foushee          Valerie                 Jean    NaN      NaN
# NC      Edwards  Charles (Chuck)               Marion    NaN      NaN
# NC       Nickel           George  Wiley (uses as 1st)    III      NaN
# NC      Jackson          Jeffrey                Neale    NaN      NaN
#
#                    full_name   birthday gender type state  ...  lis_id  \
# state                                                      ...
# SC            Lindsey Graham 1955-07-09      M  sen    SC  ...    S293
# SC          James E. Clyburn 1940-07-21      M  rep    SC  ...     NaN
# SC               Jeff Duncan 1966-01-07      M  rep    SC  ...     NaN
# SC                 Tim Scott 1965-09-19      M  sen    SC  ...    S365
# SC                Joe Wilson 1947-07-31      M  rep    SC  ...     NaN
# SC              Ralph Norman 1953-06-20      M  rep    SC  ...     NaN
# SC     William R. Timmons IV 1984-04-30      M  rep    SC  ...     NaN
# SC                Nancy Mace 1977-12-04      F  rep    SC  ...     NaN
# SC               Russell Fry 1985-01-31      M  rep    SC  ...     NaN
# NC             Virginia Foxx 1943-06-29      F  rep    NC  ...     NaN
# NC        Patrick T. McHenry 1975-10-22      M  rep    NC  ...     NaN
# NC            Richard Hudson 1971-11-04      M  rep    NC  ...     NaN
# NC             Alma S. Adams 1946-05-27      F  rep    NC  ...     NaN
# NC              David Rouzer 1972-02-16      M  rep    NC  ...     NaN
# NC               Thom Tillis 1960-08-30      M  sen    NC  ...    S384
# NC                  Ted Budd 1971-10-21      M  sen    NC  ...    S417
# NC                Dan Bishop 1964-07-01      M  rep    NC  ...     NaN
# NC         Gregory F. Murphy 1963-03-05      M  rep    NC  ...     NaN
# NC           Deborah K. Ross 1963-06-20      F  rep    NC  ...     NaN
# NC          Kathy E. Manning 1956-12-03      F  rep    NC  ...     NaN
# NC           Donald G. Davis 1971-08-29      M  rep    NC  ...     NaN
# NC        Valerie P. Foushee 1956-05-07      F  rep    NC  ...     NaN
# NC             Chuck Edwards 1960-09-13      M  rep    NC  ...     NaN
# NC              Wiley Nickel 1975-11-23      M  rep    NC  ...     NaN
# NC              Jeff Jackson 1982-09-12      M  rep    NC  ...     NaN
#
#                    fec_ids   cspan_id govtrack_id votesmart_id  \
# state
# SC     S0SC00149,H4SC03087    36782.0      300047      21992.0
# SC               H2SC02042    21607.0      400075      27066.0
# SC               H0SC03077    62713.0      412472      47967.0
# SC     H0SC01279,S4SC00240   623506.0      412471      11940.0
# SC               H2SC02059  1002567.0      400433       3985.0
# SC               H8SC05158    61996.0      412738      47930.0
# SC               H8SC04250        NaN      412815     168923.0
# SC               H0SC01394        NaN      456843          NaN
# SC               H2SC07280        NaN      456938          NaN
# NC               H4NC05146  1013052.0      400643       6051.0
# NC               H4NC10047  1007062.0      400644      21031.0
# NC               H2NC08185    79622.0      412550     136448.0
# NC               H4NC12100    76386.0      412607       5935.0
# NC               H2NC07096    79710.0      412641     102964.0
# NC               S4NC00162    77055.0      412668      57717.0
# NC               H6NC13129   103513.0      412712     171489.0
# NC               H0NC09187        NaN      412844      92423.0
# NC               H0NC03172        NaN      412845     166135.0
# NC               H0NC02125        NaN      456831          NaN
# NC               H8NC13067        NaN      456832          NaN
# NC               H2NC02287        NaN      456912          NaN
# NC               H2NC06114        NaN      456913          NaN
# NC               H2NC14050        NaN      456914          NaN
# NC               H2NC14019        NaN      456915          NaN
# NC               H2NC14076        NaN      456916          NaN
#
#                      ballotpedia_id washington_post_id icpsr_id  \
# state
# SC                   Lindsey Graham                NaN  29566.0
# SC                 James E. Clyburn                NaN  39301.0
# SC                      Jeff Duncan                NaN  21174.0
# SC                        Tim Scott                NaN  21173.0
# SC                       Joe Wilson                NaN  20138.0
# SC                     Ralph Norman                NaN  21753.0
# SC                  William Timmons                NaN  21974.0
# SC                       Nancy Mace                NaN      NaN
# SC                              NaN                NaN      NaN
# NC                    Virginia Foxx                NaN  20521.0
# NC               Patrick T. McHenry                NaN  20522.0
# NC                   Richard Hudson                NaN  21346.0
# NC                       Alma Adams                NaN  21545.0
# NC                     David Rouzer                NaN  21544.0
# NC     Thom Tillis (North Carolina)                NaN  41504.0
# NC                         Ted Budd                NaN  21708.0
# NC                       Dan Bishop                NaN  21986.0
# NC                   Gregory Murphy                NaN  21987.0
# NC                     Deborah Ross                NaN      NaN
# NC                              NaN                NaN      NaN
# NC                              NaN                NaN      NaN
# NC                              NaN                NaN      NaN
# NC                              NaN                NaN      NaN
# NC                              NaN                NaN      NaN
# NC                              NaN                NaN      NaN
#
#                                wikipedia_id  years
# state
# SC                           Lindsey Graham     67
# SC                              Jim Clyburn     82
# SC                 Jeff Duncan (politician)     57
# SC                                Tim Scott     57
# SC         Joe Wilson (American politician)     75
# SC                             Ralph Norman     69
# SC                          William Timmons     38
# SC                               Nancy Mace     45
# SC                 Russell Fry (politician)     38
# NC                            Virginia Foxx     79
# NC                          Patrick McHenry     47
# NC     Richard Hudson (American politician)     51
# NC                               Alma Adams     76
# NC                             David Rouzer     51
# NC                              Thom Tillis     62
# NC                                 Ted Budd     51
# NC                               Dan Bishop     58
# NC                 Greg Murphy (politician)     60
# NC                          Deborah K. Ross     59
# NC                            Kathy Manning     66
# NC                          Donald G. Davis     51
# NC                          Valerie Foushee     66
# NC                            Chuck Edwards     62
# NC                             Wiley Nickel     47
# NC                Jeff Jackson (politician)     40
#
# [25 rows x 37 columns]

# %% [markdown]
# Use the loc command to retrieve all legislators from California, Oregon and Washington and only get their full name, state, party and age

# %%
legislators.loc[['CA', 'OR', 'WA']][['full_name', 'state', 'party', 'years']]
# Out:
#                      full_name state       party  years
# state
# CA            Dianne Feinstein    CA    Democrat     89
# CA                 Ken Calvert    CA  Republican     69
# CA                    Judy Chu    CA    Democrat     69
# CA                   Jim Costa    CA    Democrat     70
# CA               Anna G. Eshoo    CA    Democrat     80
# ...                        ...   ...         ...    ...
# WA                Dan Newhouse    WA  Republican     67
# WA             Pramila Jayapal    WA    Democrat     57
# WA                 Kim Schrier    WA    Democrat     54
# WA          Marilyn Strickland    WA    Democrat     60
# WA     Marie Gluesenkamp Perez    WA    Democrat     34
#
# [74 rows x 4 columns]

# %%
legislators.loc[['CA', 'OR', 'WA'],\
['full_name', 'state', 'party', 'years']]
# Out:
#                      full_name state       party  years
# state
# CA            Dianne Feinstein    CA    Democrat     89
# CA                 Ken Calvert    CA  Republican     69
# CA                    Judy Chu    CA    Democrat     69
# CA                   Jim Costa    CA    Democrat     70
# CA               Anna G. Eshoo    CA    Democrat     80
# ...                        ...   ...         ...    ...
# WA                Dan Newhouse    WA  Republican     67
# WA             Pramila Jayapal    WA    Democrat     57
# WA                 Kim Schrier    WA    Democrat     54
# WA          Marilyn Strickland    WA    Democrat     60
# WA     Marie Gluesenkamp Perez    WA    Democrat     34
#
# [74 rows x 4 columns]

# %% [markdown]
# ## Exercise 10: Economics Data Example
# ### Task 1: Explore the data
# Import the data from the [Lectures in Quantiatives Economics](https://github.com/QuantEcon/lecture-source-py) regarding minimum wages in countries round the world in US Dollars.  You can view the data [here](https://github.com/QuantEcon/lecture-source-py/blob/master/source/_static/lecture_specific/pandas_panel/realwage.csv) and you can access the data file here: https://raw.githubusercontent.com/QuantEcon/lecture-source-py/master/source/_static/lecture_specific/pandas_panel/realwage.csv.  Then perform the following
#
# Import and print the first 5 lines of data to explore what is there.

# %% [markdown]
# Find the shape of the data.

# %% [markdown]
# List the column names.

# %% [markdown]
# Identify the data types. Do they match what you would expect?

# %% [markdown]
# Identify columns with missing values.

# %% [markdown]
# Identify if there are duplicated entires.

# %% [markdown]
# How many unique values per row are there.  Do these look reasonable for the data type and what you know about what is stored in the column?

# %% [markdown]
# ### Task 2: Explore More
# Retrieve descriptive statistics for the data.

# %% [markdown]
# Identify all of the countries listed in the data.

# %% [markdown]
# Convert the time column to a datetime object.

# %% [markdown]
# Identify the time points that were used for data collection. How many years of data collection were there? What time of year were the data collected?

# %% [markdown]
# Because we only have one data point collected per year per country, simplify this by creating a new `Series` with just the year.  Print the first 5 rows to confirm the column was added.

# %% [markdown]
# There are two pay periods.  Retrieve them in a list of just the two strings

# %% [markdown]
# ### Task 3: Clean the data
# We have no duplicates in this data so we do not need to consider removing those, but we do have missing values in the `value` column. Lets remove those.  Check the dimensions afterwards to make sure they rows with missing values are gone.

# %% [markdown]
# ### Task 4:  Indexing
# Use boolean indexing to retrieve the rows of annual salary in United States

# %% [markdown]
# Do we have enough data to calculate descriptive statistics for annual salary in the United States in 2016?

# %% [markdown]
# Use loc to calculate descriptive statistics for the hourly salary in the United States and then again separately for Ireland. Hint: you will have to set row indexes.

# %% [markdown]
# Now do the same for Annual salary
